# %% [markdown]
# ### Strings

# %% [markdown]
# #####  a string is a sequence of characters used to store and manipulate text. Strings are immutable, meaning that once you create a string, you cannot change its individual characters directly

# %%
# Single and double quotes work exactly the same
greeting = 'Hello'
name = "Alice"

# Triple quotes allow you to write text across multiple lines
multiline_text = """This is a string
that spans across
multiple lines."""

# %%
print(greeting)
print(name)

print(greeting +" "+ name)
# Out:
# Hello
# Alice
# Hello Alice

# %%
print(multiline_text)
# Out:
# This is a string
# that spans across
# multiple lines.

# %% [markdown]
# **Indexing** -  Grab a single letter

# %%
a = "hello learner"
index = a[11]
print(index)
# Out:
# e

# %%
index=a[-5]
print(index)
# Out:
# a

# %%
a = "how's your learning going on?"
index = a[12]
print(index)
# Out:
# e

# %% [markdown]
# **Slicing of string** - Grab a chunk [start:stop_before]

# %%
c = "Hello learner, how are you"
slice = c[3:9]
print(slice)
# Out:
# lo lea

# %%
## skip with 1 ltter
slice =c[4:15:2]
print(slice)
# Out:
# olanr

# %% [markdown]
# **Finding the length of string**

# %%
a = "this is the string topic of python"
result = len(a)
print(result)
# Out:
# 34

# %%
b= "hello world"
print(len(b))
# Out:
# 11

# %% [markdown]
# **upper**

# %%
a = "hello how are you"
result = a.upper()
print(result)
# Out:
# HELLO HOW ARE YOU

# %% [markdown]
# **lower**

# %%
a = "HELLO HOW ARE YOU"
result = a.lower()
print(result)
# Out:
# hello how are you

# %% [markdown]
# **Replace**

# %%
a = "hello, may i know your name"
result = a.replace("hello", "bye")
print(result)
# Out:
# bye, may i know your name

# %% [markdown]
# **find**

# %%
a ="python is easy to learn"
result = a.find("i")
print(result)
# Out:
# 7
