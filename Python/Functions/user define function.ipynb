# %% [markdown]
# ### User Define fucntion**

# %% [markdown]
# ###### User-defined functions are custom blocks of code that you build yourself to perform specific tasks.

# %% [markdown]
# **Creating a user defined function**

# %%
def my_function():
    print("Hello world")

# %% [markdown]
# **calling a function**

# %%
my_function()
# Out:
# Hello world

# %%
def contact():
    print("contact details of the school")
    print("Delhi public school")
    print("Delhi")
    print("788252585")
    print("delhipulicschool@gmail.com")

# %%
for i in range(4):
    a = input("Enter the student name")
    b = float(input("enter the percentage of student:"))
    print()
    contact()
# Out:
# Enter the student name Akansha
# enter the percentage of student: 78
# contact details of the school
# Delhi public school
# Delhi
# 788252585
# delhipulicschool@gmail.com
# Enter the student name vinay
# enter the percentage of student: 79
# contact details of the school
# Delhi public school
# Delhi
# 788252585
# delhipulicschool@gmail.com
# Enter the student name swati
# enter the percentage of student: 96
# contact details of the school
# Delhi public school
# Delhi
# 788252585
# delhipulicschool@gmail.com
# Enter the student name soham
# enter the percentage of student: 85
# contact details of the school
# Delhi public school
# Delhi
# 788252585
# delhipulicschool@gmail.com

# %% [markdown]
# **Argument**

# %%
def name(fname):
    print(fname+ " singh")

# %%
name("Riya")
# Out:
# Riya singh

# %%
def fullname(fname, lname):
    print(fname+ "" + lname)

# %%
fullname("Riya", " sharma")
# Out:
# Riya sharma

# %%
#Wap to calcuate the electricity bill

def electricity(n):
    if n<=500:
        print("Your bill is Rs", n*5)
    elif n >500 and n<=700:
        print("Your bill is Rs", n*10)
    elif n>700 and n<=1000:
        print("your bill is Rs", n*15)
    else:
        print("your bill is Rs", n*20)

# %%
electricity(120)
# Out:
# Your bill is Rs 600

# %%
for n in range(2):
    a = input("Enter customer name")
    n = int(input("enter your electricity unit"))
    electricity(n)
# Out:
# Enter customer name mohan
# enter your electricity unit 78
# Your bill is Rs 390
# Enter customer name om
# enter your electricity unit 785
# your bill is Rs 11775
