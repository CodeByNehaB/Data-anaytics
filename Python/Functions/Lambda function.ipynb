# %% [markdown]
# ### Lambda function

# %% [markdown]
# ##### Lambda fucntion are small anonymous function defined using the lambda keyword. they can have any number of arguments but only one expression. They are commonly used for short operation or as arguments to higher-order function.

# %%
# syntax

lambda arguments: expression

# %%
def addition(a, b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition = lambda a,b: a+b
type(addition)
print(addition(3,5))
# Out:
# 8

# %%
def even(num):
    if num%2==0:
        return True
    else:
        return False
even(4)
# Out:
# True

# %%
even = lambda num: num%2==0
even(121)
# Out:
# False

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition = lambda x,y,z: x+y+z
print(addition(67,98,83))
# Out:
# 248
