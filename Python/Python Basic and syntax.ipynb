# %%
print("Hello world!, we are learning data analytics course")
# Out:
# Hello world!, we are learning data analytics course

# %%
#This is the comment
print("Today we are learning about the comment that help us to understand code")
# Out:
# Today we are learing about the comment that help us to understand code

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Syntax - syntax refer to the set of rules that define the combination of symbol that are considered to be correctly structured program in a language.
#
# Sematics refer to the meaning or the interpretation of the symbol, character and commands in lanuguage. it is about the code is supposed to do when it runs.
