# %% [markdown]
# ## Library

# %% [markdown]
# Python's standard library is a vast collection of modules and package that come bundled with python, providing a wide range of functionalities out of the box.

# %%
import array

arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(4))
print(math.pi)
# Out:
# 2.0
# 3.141592653589793

# %%
# random

import random

print(random.randint(1,10))
print(random.choice(['apple', 'banana','cheery']))
# Out:
# 6
# banana

# %% [markdown]
# ### file and directory access

# %%
import os
#The os.getcwd() function stands for "Get Current Working Directory".
print(os.getcwd())
# Out:
# E:\neha work\Data Analytics\Python\ModuleandPackages

# %%
#
#The os.mkdir('test_dir') function stands for "Make Directory".
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files

import shutil

# %%
# make the copy of source text file
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization
import json
data = {'name':'neha', 'age':24}


json_str = json.dumps(data)
print(json_str)
print(type(json_str))


passed_data = json.loads(json_str)
print(passed_data)
print(type(passed_data))
# Out:
# {"name": "neha", "age": 24}
# <class 'str'>
# {'name': 'neha', 'age': 24}
# <class 'dict'>

# %%
## csv  - A CSV file stands for Comma-Separated Values.

import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['krish',32])


with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
## Datetime - The datetime library is a built-in Python module used for working with dates and times.

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days=2)
print(yesterday)
# Out:
# 2026-08-22 13:54:43.367557
# 2026-08-20 13:54:43.367557

# %%
# time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1787387141.95034
# 1787387143.9513805

# %%
## Regular expression
#A Regular Expression (often called Regex or RegEx) is a powerful tool used to search for, match, and manipulate text based on specific patterns

import re

pattern = r'\d+'
text = 'There are 124 apples'

match = re.search(pattern, text)
print(match.group())
# Out:
# 124
