# %% [markdown]
# ### Conditional statement

# %% [markdown]
# ##### Conditional statement in Python control the flow of execution by running the block of code when certain condition to True.

# %% [markdown]
# ### If Statement

# %%
### Execute code only if only the given condition is true

age = int(input("Enter your age"))

if age>= 18:
    print("You are eligible for driving the Vehicle")
# Out:
# Enter your age 18
# You are eligible for driving the Vehicle

# %% [markdown]
# ### If-else Statement

# %%
### The else statement execute the block of code if the condition in if statement is false

Age = int(input("Enter your age"))

if Age >= 18:
    print("Your are eligible for vote")
else:
    print("You are minor")
# Out:
# Enter your age 15
# You are minor

# %% [markdown]
# ### Elif statement

# %%
### Elif allow you to check multiple condtions. It's stand for "else-if".

Age = int(input("Enter your age"))

if Age <=13:
    print("You are a child")
elif Age < 18:
    print("You are a teenager")
else:
    print("You are a adult")
# Out:
# Enter your age 18
# You are a adult

# %% [markdown]
# ### Nested condition statement

# %%
### You can place conditional blocks inside other conditional blocks to evaluate multi-layered rules

num = int(input("Enter your Number"))

if num > 0:
    print("The number is positive")
    if num %2 ==0:
        print("The number is Even")
    else:
        print("The number is odd")
else:
    print("The number is Zero or Negetive")
# Out:
# Enter your Number 15
# The number is positive
# The number is odd

# %% [markdown]
# ### Practicle Example

# %%
### Determine the this year is leap year or not
year = int(input("Enter your year"))

if year %4 ==0:
    if year % 100== 0:
        if year %400 ==0:
            print(f"{year} is leap year")
        else:
            print(f"{year} is not a leap year")
    else:
        print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter your year 2014
# 2014 is not a leap year

# %% [markdown]
#  ### Simple calculator example

# %%
num1 = float(input("Enter your first number"))
num2 = float(input("Enter your second number"))

operator = input("Enter operator (+,-,*,/ /
: )")


if operator == "+":
    result = num1 + num2
elif operator == "-":
    result = num1 - num2
elif operator == "*":
    result = num1 * num2
elif operator =="/":
    if num2 !=0:
       result =  num1 /num2
    else:
       result = "Zero is not divided"
else:
   result = "Invalid operation"
print(result)
# Out:
# Enter your first number 4
# Enter your second number 0
# Enter operator (+,-,*,/: ) /
# Zero is not divided

# %%
## WAP to calculate the percentage of a student in the subject maths, science, socila, end, hindi

x = input("Enter the name of the studnet")
a= int(input("Enter the marks of english"))
b=  int(input("Enter the marks of Hindi"))
c=  int(input("Enter the marks of Maths"))
d = int(input("Enter the marks of social"))
e = int(input("Enter the marks of science"))

average = (a+b+c+d+e)/5
print(f"The percentage of the {x} is {average}")
# Out:
# Enter the name of the studnet Neha
# Enter the marks of english 78
# Enter the marks of Hindi 96
# Enter the marks of Maths 89
# Enter the marks of social 78
# Enter the marks of science 96
# The percentage of the Neha is 87.4

# %%
if  average >90:
    print("Grade- A+")
elif average >80:
    print("Grade- A")
elif average> 65:
    print("Grade - B")
elif average > 45:
    print("Grade -C")
elif average > 35:
    print("Grade -D")
else:
    print("Grade -F")
# Out:
# Grade- A

# %%
### wap to display Hello if number entered by a user is a multiple of 5 else print bye


a = int(input("Enter thr number"))
if a %5 ==0:
    print("Hello")
else:
    print("Bye")
# Out:
# Enter thr number 12
# Bye
