# %%
print("Hello world!, we are learning data analytics course")
# Out:
# Hello world!, we are learning data analytics course

# %%
#This is the comment
print("Today we are learning about the comment that help us to understand code")
# Out:
# Today we are learing about the comment that help us to understand code

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Syntax - syntax refer to the set of rules that define the combination of symbol that are considered to be correctly structured program in a language.
#
# Sematics refer to the meaning or the interpretation of the symbol, character and commands in lanuguage. it is about the code is supposed to do when it runs.

# %%
#Basic rule of the Python
# Case sensetivity - python is case sensetive

name = "Neha"
Name = "Bawankar"

print(name)
print(Name)
# Out:
# Neha
# Bawankar

# %% [markdown]
# Intendation - Intendation in python used to define the structure and hierarchy of the code. unlike many other programming language that use braces {} to delimit block of code. pyhton use intendation of determine the grouping of statements.

# %%
#Intendation
# python use intendation to define blocks of codes. consistent of use spaces or tab is required.
age = 25
if age>24:
    print("Intendation Space")

print("No Intendation ")
# Out:
# Intendation Space
# No Intendation

# %%
#This is single in comments
print("Hello world")
# Out:
# Hello world

# %%
#Line continuation
#Use a backslash(\) to continue a statement to the next line

total = 1+2+3+4+5+6+7+\
4+56+2+4

print(total)
# Out:
# 94

# %%
#Multiple statements on a single line

x =5;y=10;z =x+y;

print(z)
# Out:
# 15

# %%
#Understand semantics in python
# Variable assigments
age =32  ## age is an integer
name ="Neha" # name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Type inference
variable =10
print(type(variable))
variable="Vipul"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#code example of intendation

if True:
    print("This is my correct intendation")
    if False:
          print("This one not print")
    print("This will print")
print("Outside the if blocks")
# Out:
# This is my correct intendation
# This will print
# Outside the if blocks
