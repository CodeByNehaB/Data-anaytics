# %%
import re
from pathlib import Path
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
sns.set_theme(style="whitegrid", palette="deep")

# %% [markdown]
# ## chart 1 - Average sale  price by model

# %%
ordered = model_summary["avg_sale_price"].astype(float).sort_values()
ordered
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ordered = model_summary["avg_sale_price"].astype(float).sort_values()
#       2 ordered
#
# NameError: name 'model_summary' is not defined
